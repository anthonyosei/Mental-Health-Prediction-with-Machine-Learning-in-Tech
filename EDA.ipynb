# %% [markdown]
# <a href="https://colab.research.google.com/github/anthonyosei/Mental-Health-Prediction-with-Machine-Learning-in-Tech/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# locate drive and mount the storage
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load the cleaned dataset
df = pd.read_csv('/content/drive/MyDrive/MentalHealthPredictionProject - Copy/cleaned_df.csv')

# %%
# display the datafrane
df
# Out:
#        Is self-employed Comp_employees Works at a tech company  \
# 0                 False         26-100                    True
# 1                 False         26-100                    True
# 2                 False         26-100                    True
# 3                 False         26-100                    True
# 4                 False         26-100                    True
# ...                 ...            ...                     ...
# 59803             False        100-500                    True
# 59804             False        100-500                    True
# 59805             False        100-500                    True
# 59806             False        100-500                    True
# 59807             False        100-500                    True
#
#        Do you have previous employers fam_mh_illness prev_mh Has MHD  \
# 0                                True             No     Yes      No
# ...

# %%
# Is self-employed

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Is self-employed').size().plot(kind='barh', color=sns.color_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ##Visualizing Self Employment Data
#
# By using the cleaned_df.csv' dataset, focusing on the 'Is self-employed' column. As the outcome displays horizontal bar plot providing clear representation visually of the proportion of self- employed individuals who took part in the survey. This will be used to explore potential correlations between self-employment and mental health conditions, prompting further investigation.

# %%
df.describe(include='all')
# Out:
#        Is self-employed Comp_employees Works at a tech company  \
# count             59808          59808                   47838
# unique                2              6                       2
# top               False         26-100                    True
# freq              47838          24192                   36876
# mean                NaN            NaN                     NaN
# std                 NaN            NaN                     NaN
# min                 NaN            NaN                     NaN
# 25%                 NaN            NaN                     NaN
# 50%                 NaN            NaN                     NaN
# 75%                 NaN            NaN                     NaN
# max                 NaN            NaN                     NaN
#
#        Do you have previous employers fam_mh_illness prev_mh Has MHD  \
# count                           59808          59808   59808   59808
# ...

# %%
# check the rows and columns in the dataframe
df.shape
# Out:
# (59808, 20)

# %%
# check the information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59808 entries, 0 to 59807
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Is self-employed                59808 non-null  bool
#  1   Comp_employees                  59808 non-null  object
#  2   Works at a tech company         47838 non-null  object
#  3   Do you have previous employers  59808 non-null  bool
#  4   fam_mh_illness                  59808 non-null  object
#  5   prev_mh                         59808 non-null  object
#  6   Has MHD                         59808 non-null  object
#  7   diagnosed_mh                    59808 non-null  bool
#  8   So:What_diagnosis?              59808 non-null  object
#  9   Sought_mh_treat                 59808 non-null  bool
#  10  Age                             59808 non-null  int64
#  11  Gender                          59808 non-null  object
# ...

# %%
df['Is self-employed'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# ### DATA EXPLORATORY

# %%
# plot the count of ages in the dataframe
df['Age'].value_counts().plot(kind = 'bar', figsize=(10,10))
plt.show()

# %% [markdown]
# The age of all people in the dataset were taken into account. We counted how many people belong to each group and then created a bar chart where they corresponds to the number of people in that group. The visualisation was needed to help understand the dataset age distribution.

# %%
sns.displot(df['Age'], kde = True)
plt.title("Distribution - Age")
plt.xlabel("Age")
# Out:
# Text(0.5, 9.444444444444438, 'Age')

# %% [markdown]
# Gender

# %%
# Plot the count of genders in the dataframe
df['Gender'].value_counts().plot(kind = 'bar', figsize=(8,8))
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# The 'Gender' column, counts the occurrences of each gender, and then creates a bar chart to visually represent the gender distribution within the dataset. This helps in understanding the representation of different genders within the data being analysed

# %%
# check self employed with their treatment as hue
plt.figure(figsize=(10,40))
plt.subplot(9,2,1)
sns.countplot(data = df, x = 'Is self-employed', hue = 'diagnosed_mh')
plt.title("Employment Type")
# Out:
# Text(0.5, 1.0, 'Employment Type')

# %%
plt.figure(figsize=(10,40))
plt.subplot(9,2,2)
sns.countplot(data = df , x ='fam_mh_illness', hue = 'diagnosed_mh')
plt.title("Family History")
# Out:
# Text(0.5, 1.0, 'Family History')

# %%
plt.figure(figsize=(10,40))
plt.subplot(9,2,3)
sns.countplot(data= df , x= 'Work remotely', hue = 'diagnosed_mh')
plt.title("Work Remotely")
# Out:
# Text(0.5, 1.0, 'Work Remotely')

# %%
# check Gender with their treatment as hue
plt.figure(figsize=(10,40))
plt.subplot(9,2,1)
sns.countplot(data = df, x = 'Gender', hue = 'diagnosed_mh')
plt.title("Gender")
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
# check Gender with their treatment as hue
plt.figure(figsize=(10,40))
plt.subplot(9,2,1)
sns.countplot(data = df, x = 'prev_mh', hue = 'diagnosed_mh')
plt.title("Previous Mental Health")
plt.xlabel('Previous mental health condition')
plt.show()

# %%
# check Gender with their treatment as hue
plt.figure(figsize=(10,40))
plt.subplot(9,2,1)
sns.countplot(data = df, x = 'Country work', hue = 'diagnosed_mh')
plt.title("Country Working")
plt.xlabel('Country')
plt.xticks(rotation=20)
plt.show()

# %%
# check Gender with their treatment as hue
plt.figure(figsize=(10,40))
plt.subplot(9,2,1)
sns.countplot(data = df, x = 'Works at a tech company', hue = 'diagnosed_mh')
plt.title("Tech Company")
plt.xlabel('Tech Company')
plt.show()

# %%
# check Tech Company with their treatment as hue
plt.figure(figsize=(10,40))
plt.subplot(9,2,1)
sns.countplot(data = df, x = 'Age Group', hue = 'diagnosed_mh')
plt.title("Tech Company")
plt.xlabel('Tech Company')
plt.xticks(rotation=90)
plt.show()

# %%
# Plot the count of individuals diagnosed with mental health in the dataframe
pt =df['diagnosed_mh'].value_counts().plot(kind = 'bar', figsize=(8,6))
for p in pt.patches:
    height = round(p.get_height())
    pt.annotate(f'{round(height/59808*100, 2)}%',
                xy=(p.get_x() + p.get_width() / 2, height),
                xytext=(0, 3),  # 3 points vertical offset
                textcoords="offset points",
                ha='center',
                va='bottom')

plt.show()

# %%
#correlation matrix

corrmat = numeric_columns.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
plt.show()

#treatment correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'treatment')['treatment'].index
cm = np.corrcoef(train_df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-693642a3d28e> in <cell line: 3>()
#       1 #correlation matrix
#       2
# ----> 3 corrmat = numeric_columns.corr()
#       4 f, ax = plt.subplots(figsize=(12, 9))
#       5 sns.heatmap(corrmat, vmax=.8, square=True);
#
# NameError: name 'numeric_columns' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59808 entries, 0 to 59807
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Is self-employed                59808 non-null  bool
#  1   Comp_employees                  59808 non-null  object
#  2   Works at a tech company         47838 non-null  object
#  3   Do you have previous employers  59808 non-null  bool
#  4   fam_mh_illness                  59808 non-null  object
#  5   prev_mh                         59808 non-null  object
#  6   Has MHD                         59808 non-null  object
#  7   diagnosed_mh                    59808 non-null  bool
#  8   So:What_diagnosis?              59808 non-null  object
#  9   Sought_mh_treat                 59808 non-null  bool
#  10  Age                             59808 non-null  int64
#  11  Gender                          59808 non-null  object
# ...

# %%
#Age vs No. of Employees
fig,ax = plt.subplots(figsize=(8, 6))
sns.barplot(data = df, x =  df['Comp_employees'], y = df['Age'], ax = ax)
plt.title('Age Group vs Group size')
plt.xlabel('Group size at Work')
plt.ylabel('Age')
ticks = plt.setp(ax.get_xticklabels(), rotation=90)

# %% [markdown]
# ###Age VS Number of Employees
